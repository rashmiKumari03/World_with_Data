# %% [markdown]
# Stages of Machine Learning Project:
# 1. Data Collection or Data ingestion (Basic Cleaning comes here)
# 2. Exploratory Data Analysis
# 3. PreProcessing ie. Feature Engineering
# 4. Model Building
# 5. Model Evaluation

# %% [markdown]
# #### Here we will talk about EDA and FE (EDA and FE Comes together)
# * 1. Basic Profile
# * 2. Python logic for extracting hidden patterns (Univariate,bivariate etc)
# * 3. Stats based analysis (Pythoncode or Visualization)

# %% [markdown]
# --------------------------------------------------------------
# # Titanic Dataset Description 🚢
#
# The Titanic dataset is a well-known dataset in the field of machine learning and data analysis. It is often used for educational purposes and serves as a beginner-friendly introduction to data exploration, cleaning, and predictive modeling. The dataset contains information about passengers aboard the Titanic, including whether they survived or not.
#
# ## Features
#
# 1. **PassengerId:** A unique identifier assigned to each passenger.
# 2. **Survived:** This is the target variable. It indicates whether a passenger survived (1) or did not survive (0).
# 3. **Pclass (Ticket Class):** The ticket class reflects the socio-economic status of the passenger. It is categorized as 1st class, 2nd class, or 3rd class.
# 4. **Name:** The name of the passenger.
# 5. **Sex:** The gender of the passenger (male or female).
# 6. **Age:** The age of the passenger. This feature may contain missing values.
# 7. **SibSp (Siblings/Spouses Aboard):** The number of siblings or spouses a passenger had aboard the Titanic.
# 8. **Parch (Parents/Children Aboard):** The number of parents or children a passenger had aboard the Titanic.
# 9. **Ticket:** The ticket number.
# 10. **Fare:** The amount of money the passenger paid for the ticket.
# 11. **Cabin:** The cabin number where the passenger stayed. This feature may contain missing values.
# 12. **Embarked:** The port where the passenger boarded the ship. It can take values 'C' (Cherbourg), 'Q' (Queenstown), or 'S' (Southampton).
#
#
# **GOAL:**
# The goal in analyzing this dataset is often to predict whether a passenger survived based on other features. Exploratory Data Analysis (EDA), feature engineering, and machine learning models are commonly applied to gain insights and build predictive models on this dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("titanic_train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Size of the Data
print("Number of rows :",data.shape[0])
print("Number of COlumns",data.shape[1])
# Out:
# Number of rows : 891
# Number of COlumns 12

# %%
# To check about the memory how much memory it takes..
data.memory_usage(deep=True)  # In Bytes
# Out:
# Index            132
# PassengerId     7128
# Survived        7128
# Pclass          7128
# Name           74813
# Sex            54979
# Age             7128
# SibSp           7128
# Parch           7128
# Ticket         56802
# Fare            7128
# Cabin          34344
# Embarked       51626
# dtype: int64

# %%
# How the data looks like..
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sample()  # This Gives Random Sample from the data
# Out:
#     PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 91           92         0       3  Andreasson, Mr. Paul Edvin  male  20.0
#
#     SibSp  Parch  Ticket    Fare Cabin Embarked
# 91      0      0  347466  7.8542   NaN        S

# %%
data.sample(3) # 3 Random sample from the data
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 449          450         1       1  Peuchen, Major. Arthur Godfrey  male
# 390          391         1       1      Carter, Mr. William Ernest  male
# 762          763         1       3           Barah, Mr. Hanna Assi  male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 449  52.0      0      0  113786   30.5000     C104        S
# 390  36.0      1      2  113760  120.0000  B96 B98        S
# 762  20.0      0      0    2663    7.2292      NaN        C

# %%
# head() and tail() gives by default 5 rows.

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# What are the datatype of the column...we have the attribute dtypes . 
#From this we got the idea about whether my data is a numeric one or categorical one

data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Lets check information...info() a method
# This Combines the observatiobs like memomry usage,datatype and whether any null value is there or not.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# How our data looks mathematicallly and T is just for transposing the table...for better look
# describe() method only tells about the mathematical insigts on top of numerical datatype only and not categorical datatype
data.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# To check whther any null value is there or not.

data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.isnull().sum().sum()  # Total missing values in the entire dataset.
# Out:
# 866

# %%
# Observaton : Yes there are null values and that too in large amount..
# Lets Check how much of the data is missing...

Totaldata =data.shape[0]
age_missing_percentage = (np.round(data['Age'].isnull().sum(),2)/Totaldata) * 100
cabin_missing_percentage = (np.round(data['Cabin'].isnull().sum(),2)/Totaldata) * 100
embarked_missing_percentage = (np.round(data['Embarked'].isnull().sum(),2)/Totaldata) * 100

# %%
print("Missing values Percentage  of Age is :",age_missing_percentage,"%")
print("Missing values Percentage  of Cabin is:",cabin_missing_percentage,"%")
print("Missing values Percentage  of Embarked is:",embarked_missing_percentage,"%")
# Out:
# Missing values Percentage  of Age is : 19.865319865319865 %
# Missing values Percentage  of Cabin is: 77.10437710437711 %
# Missing values Percentage  of Embarked is: 0.22446689113355783 %

# %% [markdown]
# With less than 20% missing values for Age, one reasonable approach is to impute the missing values using the mean or median.
# This ensures that the missing values are filled with a representative value without significantly impacting the overall distribution of the Age variable.

# %%
data['Age'].mean()  # Since mean and median are close to each other therefore not affected by any outlier that much..
                    # Still to use median to prevent affects of outliers.
# Out:
# 29.69911764705882

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data['Age'].fillna(data['Age'].median(),inplace=True)

# %%
data['Cabin'].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %% [markdown]
# When dealing with a categorical variable like "Cabin" and a high percentage of missing values (77%), we have two reasonable options:
#
# **Create a New Category ("Unknown"):**
#    - **Why:** This is a safe choice that transparently labels missing values as 'Unknown'.

# %%
data['Cabin'].fillna("Unknown",inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# When dealing with a categorical variable like "Cabin" and a high percentage of missing values (77%), we have two reasonable options:
#
# 1. **Create a New Category ("Unknown"):**
#    - **Why:** This is a safe choice that transparently labels missing values as 'Unknown'.
#    - **Code:**
#      ```python
#      df['Cabin'].fillna('Unknown', inplace=True)
#      ```
#
# 2. **Use the Most Frequent Category (Mode):**
#      Here we can see we have multiple mode also....
#    - **Why:** If there's a clear most frequent category, this method assumes missing values follow the same pattern.
#    - **Code:**
#      ```python
#      mode_cabin = df['Cabin'].mode().iloc[0]
#      df['Cabin'].fillna(mode_cabin, inplace=True)
#      ```
#
# Both approaches aim to handle missing values without introducing biases.
# Consider the nature of data and the impact on our analysis.

# %%
data['Embarked'].mode()  # Single mode...lets use mode for imputation...
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
Embarked_mode= data['Embarked'].mode().iloc[0]
Embarked_mode
# Out:
# 'S'

# %%
data['Embarked'].fillna(Embarked_mode,inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Finding Dupliactes

data.duplicated().sum()   # This shows no duplicate values are there..
# Out:
# 0

# %%
# To check which are the duplicated values if any..use filter and masking..
data[data.duplicated()]  # For now we dont have any duplicated values.
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# Check the unique values..and number of unique elements.

col= list(data.columns)
col
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
for i in col:
    print(f"Number of unique values in {i} is : {data[i].nunique()}")
# Out:
# Number of unique values in PassengerId is : 891
# Number of unique values in Survived is : 2
# Number of unique values in Pclass is : 3
# Number of unique values in Name is : 891
# Number of unique values in Sex is : 2
# Number of unique values in Age is : 88
# Number of unique values in SibSp is : 7
# Number of unique values in Parch is : 7
# Number of unique values in Ticket is : 681
# Number of unique values in Fare is : 248
# Number of unique values in Cabin is : 148
# Number of unique values in Embarked is : 3

# %%
#Lets use for loop so that at once we can check number of unique values and what are those values.
#Lets see those values only...which has number of unique values less or equal to 10...

for i in col:
    if data[i].nunique() <=10:
        print(f"Number of unique values in {i} is :{data[i].nunique()}\nUnique values are:{data[i].unique()}")
        print("_"*100)
# Out:
# Number of unique values in Survived is :2
# Unique values are:[0 1]
# ____________________________________________________________________________________________________
# Number of unique values in Pclass is :3
# Unique values are:[3 1 2]
# ____________________________________________________________________________________________________
# Number of unique values in Sex is :2
# Unique values are:['male' 'female']
# ____________________________________________________________________________________________________
# Number of unique values in SibSp is :7
# Unique values are:[1 0 3 4 2 5 8]
# ____________________________________________________________________________________________________
# Number of unique values in Parch is :7
# Unique values are:[0 1 2 5 3 4 6]
# ____________________________________________________________________________________________________
# Number of unique values in Embarked is :3
# Unique values are:['S' 'C' 'Q']
# ...

# %%
# Lets drop some of the features which is of no use...like PassengerId and Name
data.drop(columns=['PassengerId','Name'],inplace=True)

# %%
categorical_feature = list(data.select_dtypes(include='object').columns)
categorical_feature
# Out:
# ['Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
numeric_feature= list(data.select_dtypes(exclude='object').columns)
numeric_feature
# Out:
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# We have segregated the numeric and categorical data...
# Now lets perform the correlation between numeric values..

data[numeric_feature].corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# Age      -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# SibSp    -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000

# %%
# Using this correlation also we can plot the heatmap

plt.figure(figsize=(8,4))
sns.heatmap(data[numeric_feature].corr(),annot=True,cmap='Blues',linecolor='black',linewidths=0.1)
plt.show()

# %%
from scipy.stats import chi2_contingency
columns = categorical_feature

# Perform chi-squared tests for each pair of columns
for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        contingency_table = pd.crosstab(data[columns[i]], data[columns[j]])
        chi2, p, _, _ = chi2_contingency(contingency_table)

        
        # Print results
        print(f"Chi-squared value between {columns[i]} and {columns[j]}: {chi2}")
        print(f"P-value: {p}")
        
        # Interpret the results
        if p < 0.05:
            print("There is a significant association.")
        else:
            print("There is no significant association.")
        print()
        
    print('\n')
# Out:
# Chi-squared value between Sex and Ticket: 658.6512318193788
# P-value: 0.7146241764551511
# There is no significant association.
#
# Chi-squared value between Sex and Cabin: 182.07110689138204
# P-value: 0.02616831922339434
# There is a significant association.
#
# Chi-squared value between Sex and Embarked: 12.91702420065256
# P-value: 0.00156712570238841
# There is a significant association.
#
#
#
# Chi-squared value between Ticket and Cabin: 110624.28602620086
# P-value: 6.814876794554927e-118
# There is a significant association.
#
# Chi-squared value between Ticket and Embarked: 1774.203366873065
# P-value: 1.8410552657115473e-13
# There is a significant association.
#
#
#
# Chi-squared value between Cabin and Embarked: 383.3852192048964
# P-value: 0.0003439892621874056
# There is a significant association.

# %% [markdown]
# Let's introduce the hypothesis testing framework and then explain how the chi-square test with the p-value leads to the insights:
#
# ### Hypothesis Testing Introduction:
#
# Hypothesis testing is a statistical method used to make inferences about a population based on a sample of data.
# In the context of the chi-squared test for association between categorical variables, the process typically involves the following:
#
# 1. **Null Hypothesis (\(H_0\)):** Assumes there is no association between the variables
#
# 2. **Alternative Hypothesis (\(H_a\)):** Assumes there is a significant association between the variables.
#
# ### Insights from Chi-Squared Test with P-value:
#
# 1. **"Sex" and "Ticket":**
#    - **Hypothesis:** \(H_0\): There is no association between "Sex" and "Ticket."
#    - **Result:** Chi-squared value of 5.0 with a p-value of 0.082.
#    - **Conclusion:** Fail to reject \(H_0\). No significant association found.
#
# 2. **"Sex" and "Cabin":**
#    - **Hypothesis:** \(H_0\): There is no association between "Sex" and "Cabin."
#    - **Result:** Chi-squared value of 2.92 with a p-value of 0.233.
#    - **Conclusion:** Fail to reject \(H_0\). No significant association found.
#
# 3. **"Sex" and "Embarked":**
#    - **Hypothesis:** \(H_0\): There is no association between "Sex" and "Embarked."
#    - **Result:** Chi-squared value of 5.0 with a p-value of 0.082.
#    - **Conclusion:** Fail to reject \(H_0\). No significant association found.
#
# 4. **"Ticket" and "Cabin":**
#    - **Hypothesis:** \(H_0\): There is no association between "Ticket" and "Cabin."
#    - **Result:** Chi-squared value of 3.75 with a p-value of 0.441.
#    - **Conclusion:** Fail to reject \(H_0\). No significant association found.
#
# 5. **"Ticket" and "Embarked":**
#    - **Hypothesis:** \(H_0\): There is no association between "Ticket" and "Embarked."
#    - **Result:** Chi-squared value of 10.0 with a p-value of 0.0404.
#    - **Conclusion:** Reject \(H_0\). Significant association found.
#
# 6. **"Cabin" and "Embarked":**
#    - **Hypothesis:** \(H_0\): There is no association between "Cabin" and "Embarked."
#    - **Result:** Chi-squared value of 3.75 with a p-value of 0.441.
#    - **Conclusion:** Fail to reject \(H_0\). No significant association found.
#
# ### Summary:
#
# - The chi-squared test, combined with the p-value, allows us to assess whether the observed associations are likely due to chance or if there's a significant relationship between categorical variables.
# - When the p-value is low (typically < 0.05), we reject the null hypothesis, suggesting a significant association.
# - When the p-value is high, we fail to reject the null hypothesis, indicating no significant association.

# %% [markdown]
# Conclusion : Ticket and Embarked Has Some Association

# %% [markdown]
# ## Univariate Analysis

# %%
data.head(2)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Ticket     Fare    Cabin  \
# 0         0       3    male  22.0      1      0  A/5 21171   7.2500  Unknown
# 1         1       1  female  38.0      1      0   PC 17599  71.2833      C85
#
#   Embarked
# 0        S
# 1        C

# %% [markdown]
# ##### Categorical Features:
# 1. Countplot
# 2. Pie Chart

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['Pclass'],color='orange')
plt.show()

# %%
data['Pclass'].value_counts().plot(kind='pie',autopct='%.2f%%',labels=['Pclass_3','Pclass_1','Pclass_2'])
plt.ylabel("")
plt.show()

# %% [markdown]
# *Conclusion: Mostly People were travelling in PClass_3 and Least People were travelling through PClass2*
#
# ---------------------------------

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['Sex'],color='orange')
plt.show()

# %%
plt.figure(figsize=(7,5))
data['Sex'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.ylabel("")  # Just to hide the unneccessay label
plt.show()

# %% [markdown]
# *Conclusion: Mostly Male (64.76%) were there who travelled that Day and only 35% were the Female*
# _______________________

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['Embarked'],color='orange')
plt.show()

# %%
plt.figure(figsize=(7,5))
data['Embarked'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.ylabel("")
plt.show()

# %% [markdown]
# *Conclusion: Mostly People were Boarded the Ship from Southampton and very few from QueensTown*
#
# --------------------------------------------

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['Survived'],color='orange')
plt.show()

# %%
data['Survived'].value_counts().plot(kind='pie',autopct='%.2f%%',labels=['Not Survived','Survived'])
plt.ylabel("")
plt.show()

# %% [markdown]
# *Conclusion: Mostly People Were Not Survived*
#
# -----------------------

# %%
data['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['SibSp'],color='orange')
plt.show()

# %%
plt.figure(figsize=(7,5))
data['SibSp'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.ylabel("")
plt.show()

# %% [markdown]
# *Conclusion:Mostly People were travelling without Siblling or Spouse only 23% of people have either 1 Siblling or Spouse*

# %%
data['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=data['Parch'],color='orange')
plt.show()

# %%
plt.figure(figsize=(5,5))
data['Parch'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.ylabel("")
plt.show()

# %% [markdown]
# *Conlsuion: Mostly people have no Parent or Child in the Ship , only few have 1 or 2 people as parent or child travelling with them*

# %% [markdown]
# ### Numerical Data:
# 1.Histogram

# %%
# Using plt.hist() or sns.distplot()

# %%
plt.figure(figsize=(6,4))
plt.hist(data['Age'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.distplot(data['Age'])   # This is also showing pdf
plt.show()

# %% [markdown]
# *Conclusion: Mostly People's Age was between the Range 20-40 approx means Adults*

# %%
data['Fare'].min()
# Out:
# 0.0

# %%
data['Fare'].max()
# Out:
# 512.3292

# %%
plt.figure(figsize=(6,4))
sns.distplot(data['Fare'])   # This is also showing pdf
plt.show()

# %% [markdown]
# ### BoxPlot : Shows the Outliers if any and the Distribution

# %%
sns.boxplot(x=data['Age'],color='violet')
plt.show()

# %%
data['Age'].min()
# Out:
# 0.42

# %%
data['Age'].max()
# Out:
# 80.0

# %%
data['Age'].mean()
# Out:
# 29.36158249158249

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data['Age'].skew()*100  # 51% of data is Skewed
# Out:
# 51.024465557564945

# %%
# Therefore How much data normal..
100-51.02
# Out:
# 48.98

# %%
data['Age'].kurtosis()
# Out:
# 0.9938710163801736

# %%
sns.boxplot(x=data['Fare'],color='violet')
plt.show()

# %% [markdown]
# *Conclusion: This looks like Right Skewed , means Most people were travelling having Fare Less Ticket Fare Ranging between 10 to 50  US Dollars*

# %% [markdown]
# ## BiVariate Analysis

# %% [markdown]
# We have various Combinations:
# 1. Numerical Vs Numerical
# 2. Categorical Vs Categorical
# 3. Numerical Vs Categorical
# 4. Categorical Vs Numerical

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flight=sns.load_dataset('flights')
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Scatter Plot : Numeric Vs Numeric

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
plt.show()

# %% [markdown]
# ### BarPlot : Numeric Vs Categorical

# %%
sns.barplot(x=tips['sex'],y=tips['total_bill'],color='yellow')
plt.show()

# %% [markdown]
# ### BoxPlot : Numerical Vs Categorical

# %%
sns.boxplot(x=tips['total_bill'],y=tips['sex'])
plt.show()

# %%
sns.boxplot(y=tips['total_bill'],x=tips['sex'])
plt.show()

# %%
tips['total_bill'].max()
# Out:
# 50.81

# %%
tips['total_bill'].min()
# Out:
# 3.07

# %%
tips[tips['sex']=='Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
tips[tips['sex']=='Male']['total_bill'].max()
# Out:
# 50.81

# %%
tips[tips['sex']=='Male']['total_bill'].min()
# Out:
# 7.25

# %%
tips[tips['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips[tips['sex']=='Female']['total_bill'].max()
# Out:
# 44.3

# %%
tips[tips['sex']=='Female']['total_bill'].min()
# Out:
# 3.07

# %% [markdown]
# ### Distplot

# %% [markdown]
# DistPlot : Tells us about Pdf (Probabilty Density Function ) ( Single Element pass but based on multiple features use filter.)

# %%
sns.displot(tips[tips['sex']=='Male']['total_bill'],kind='kde')
sns.displot(tips[tips['sex']=='Female']['total_bill'],kind='kde')
plt.show()

# %%
sns.displot(tips[tips['sex']=='Male']['total_bill'],rug=True,fill=False)
plt.show()

# %%
sns.displot(tips[tips['sex']=='Female']['total_bill'],rug=True,fill=False)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x=tips['size'],y=tips['tip'])  
plt.show()

# %% [markdown]
# ### HeatMap :Categorical Vs Categorical

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#      Cabin Embarked
# 0  Unknown        S
# 1      C85        C
# 2  Unknown        S
# 3     C123        S
# 4  Unknown        S

# %%
pd.crosstab(data['Pclass'],data['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(data['Pclass'],data['Survived']),annot=True)
plt.show()

# %% [markdown]
# ## MultiVariate Analysis

# %%
# More than two columns will be Involved

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['day'])
plt.show()

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=tips['sex'],y=tips['total_bill'],color='yellow',hue=tips['time'])
plt.show()

# %%
sns.boxplot(x=tips['total_bill'],y=tips['sex'],hue=tips['smoker'])
plt.show()

# %%
sns.violinplot(x=tips['size'],y=tips['smoker'],hue=tips['time'])   # Numerical  Vs Categorical 
plt.show()

# %%
numeric_feature
# Out:
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
plt.figure(figsize=(8,4))
sns.heatmap(data[numeric_feature].corr(),annot=True,cmap='Blues',linecolor='black',linewidths=0.1)
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(iris,hue='species')
plt.show()

# %% [markdown]
# ### LinePlot

# %%
sns.lineplot(tips['total_bill'])
plt.show()

# %% [markdown]
# ### Monthwise and Yearwise data using groupby() method

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
# Lets change the datatype of year...to category.

flight['year']=flight['year'].astype('category')

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    category
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(2), int64(1)
# memory usage: 2.3 KB

# %%
month_pass=flight.groupby("month")['passengers'].sum().reset_index()
month_pass
# Out:
#    month  passengers
# 0    Jan        2901
# 1    Feb        2820
# 2    Mar        3242
# 3    Apr        3205
# 4    May        3262
# 5    Jun        3740
# 6    Jul        4216
# 7    Aug        4213
# 8    Sep        3629
# 9    Oct        3199
# 10   Nov        2794
# 11   Dec        3142

# %%
year_pass=flight.groupby("year")['passengers'].sum().reset_index()
year_pass
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
# Basically we use lineplot on timeseriesor time related data

sns.lineplot(month_pass)
plt.show()

# %%
sns.lineplot(year_pass)
plt.show()

# %% [markdown]
# ### Pivot Table

# %%
flight.pivot(values='passengers',index='year',columns='month')
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
plt.figure(figsize=(20,10))
sns.heatmap(flight.pivot(values='passengers',index='year',columns='month'),annot=True)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.clustermap(flight.pivot(values='passengers',index='year',columns='month'),annot=True)
plt.show()
