# %%
import pandas as pd
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips.head()

# %%
pip install pandas-profiling==3.5.0

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(tips,title='tips Profiling Report')

# %%
profile.to_file("Pandas_profiling_result.html")
